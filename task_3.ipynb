# %%
#1_3_A
hw = "Hello World";
for i in range(1000):
    print(hw);
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World
# ...

# %%
#1_3_B
n=0;
while True:
    var=int(input());
    n+=1;
    if(var!=0):
        print("Case "+str(n)+":"+str(var));
    elif(int(var)==0):
        break;
# Out:
# Case 1:3

# %%
#1_3_C
while True:
    x,y=list(map(int,input().split()));
    if x>y:
        x,y = y,x;
    elif x==0 and y==0:
        break;
    print(x,y);
# Out:
# 2 3
# 2 2
# 3 5

# %%
#1_3_D
a,b,c=list(map(int,input().split()));
c_count=0;

while True:
    if c%a==0:
        c_count+=1;
    if a==b:
        print(c_count);
        break;
    a+=1;
# Out:
# 3
