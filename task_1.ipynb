# %%
#1_1_A
print("Hello World")
print("Hello","World")
print("Hello World", end=" ")
print("Hello World", end="\n")
print("Hello World", end="\nEnd of program.\n")
# Out:
# Hello World
# Hello World
# Hello World Hello World
# Hello World
# End of program.

# %%
#1_1_B
x=int(input())
print(x**3)
# Out:
# 27

# %%
#1_1_C
l=input()
a,b = list(map(int, l.split()))
print(a*b,2*a+2*b)
# Out:
# 15 16

# %%
#1_1_D
s=int(input())
h=s//(60*60)
m=(s%(60*60))//60
s=s%60
print(f"{h}:{m}:{s}")
# Out:
# 13:2:59
